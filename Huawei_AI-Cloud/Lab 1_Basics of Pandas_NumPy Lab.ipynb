# %%
import pandas as pd
auto_df = pd.read_csv("auto_purchases.csv", index_col=0)
#type(df)
#print(df)
auto_df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
type(auto_df)
# Out:
# pandas.core.frame.DataFrame

# %%
auto_df.tail()
# Out:
#           company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 81     volkswagen      sedan        97.3   171.7         ohc             four
# 82     volkswagen      sedan        97.3   171.7         ohc             four
# 86     volkswagen      sedan        97.3   171.7         ohc             four
# 87          volvo      sedan       104.3   188.8         ohc             four
# 88          volvo      wagon       104.3   188.8         ohc             four
#
#        horsepower  average-mileage    price
# index
# 81             85               27   7975.0
# 82             52               37   7995.0
# 86            100               26   9995.0
# 87            114               23  12940.0
# 88            114               23  13415.0

# %%
auto_df.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
auto_df.head(10)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# ...

# %%
auto_df.head(15)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 6             audi        wagon       105.8   192.7         ohc
# 9              bmw        sedan       101.2   176.8         ohc
# 10             bmw        sedan       101.2   176.8         ohc
# 11             bmw        sedan       101.2   176.8         ohc
# 13             bmw        sedan       103.5   189.0         ohc
# 14             bmw        sedan       103.5   193.8         ohc
# 15             bmw        sedan       110.0   197.0         ohc
# ...

# %%
auto_df.tail()
# Out:
#           company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 81     volkswagen      sedan        97.3   171.7         ohc             four
# 82     volkswagen      sedan        97.3   171.7         ohc             four
# 86     volkswagen      sedan        97.3   171.7         ohc             four
# 87          volvo      sedan       104.3   188.8         ohc             four
# 88          volvo      wagon       104.3   188.8         ohc             four
#
#        horsepower  average-mileage    price
# index
# 81             85               27   7975.0
# 82             52               37   7995.0
# 86            100               26   9995.0
# 87            114               23  12940.0
# 88            114               23  13415.0

# %%
#Data Frame data types for selectec columns
print(auto_df['company'].dtype)
print(auto_df['wheel-base'].dtype)
print(auto_df['horsepower'].dtype)
#Check types for all the columns
auto_df.dtypes
# Out:
# object
# float64
# int64
# company              object
# body-style           object
# wheel-base          float64
# length              float64
# engine-type          object
# num-of-cylinders     object
# horsepower            int64
# average-mileage       int64
# price               float64
# dtype: object

# %%
#Selecting a column in a Data Frame
print(auto_df['company'])
auto_df.company.describe()
# Out:
# index
# 0     alfa-romero
# 1     alfa-romero
# 2     alfa-romero
# 3            audi
# 4            audi
#          ...
# 81     volkswagen
# 82     volkswagen
# 86     volkswagen
# 87          volvo
# 88          volvo
# Name: company, Length: 61, dtype: object
# count         61
# unique        16
# top       toyota
# freq           7
# Name: company, dtype: object

# %%
# First calculate means by company
company_means = auto_df.groupby(['company'])[["wheel-base", "length", "horsepower", "average-mileage", "price"]].mean()

# Then rank each metric separately
company_ranks = company_means.rank(method='dense', ascending=False)
company_means
company_ranks
# Out:
#                wheel-base  length  horsepower  average-mileage  price
# company
# alfa-romero          15.0     9.0         5.0             11.0    6.0
# audi                  5.0     5.0         7.0             12.0    5.0
# bmw                   4.0     4.0         4.0             13.0    4.0
# chevrolet            14.0    16.0        16.0              1.0   16.0
# dodge                13.0    15.0        15.0              5.0   15.0
# honda                 8.0    11.0         8.0              9.0    9.0
# isuzu                12.0    14.0        13.0              2.0    8.0
# jaguar                2.0     2.0         2.0             16.0    2.0
# mazda                 9.0    13.0        12.0              8.0   10.0
# mercedes-benz         1.0     1.0         3.0             14.0    1.0
# mitsubishi           11.0    12.0        10.0              6.0   14.0
# nissan               10.0     8.0         9.0              4.0   12.0
# ...

# %%
auto_df_rank

# %%
auto_df.mean(numeric_only=True)
# Out:
# wheel-base            98.481967
# length               173.098361
# horsepower           107.852459
# average-mileage       25.803279
# price              15387.000000
# dtype: float64

# %%
#Calculate mean salary for each company rank:
auto_df.groupby('company')[['price']].mean()
#auto_df.groupby('company')['price'].mean()
# Out:
#                       price
# company
# alfa-romero    15498.333333
# audi           16392.500000
# bmw            27213.333333
# chevrolet       6007.000000
# dodge           6303.000000
# honda          10195.000000
# isuzu           6785.000000
# jaguar         34600.000000
# mazda           9654.800000
# mercedes-benz  35040.000000
# mitsubishi      6689.000000
# nissan          8289.000000
# porsche        35528.000000
# toyota          8216.857143
# volkswagen      8435.000000
# volvo          13177.500000

# %%
#Calculate mean price for each company rank:
auto_df_sub = auto_df[auto_df['price'] > 15000]
print("Mean price for each company >15000 -> \n",auto_df_sub)

#Select only those rows that contain audi company:
auto_df_audi = auto_df[auto_df['company']=='audi']
print("Select only for audi company -> \n", auto_df_audi)
# Out:
# Mean price for each company >15000 ->
#               company   body-style  wheel-base  length engine-type  \
# index
# 1        alfa-romero  convertible        88.6   168.8        dohc
# 2        alfa-romero    hatchback        94.5   171.2        ohcv
# 4               audi        sedan        99.4   176.6         ohc
# 5               audi        sedan        99.8   177.3         ohc
# 6               audi        wagon       105.8   192.7         ohc
# 9                bmw        sedan       101.2   176.8         ohc
# 10               bmw        sedan       101.2   176.8         ohc
# 11               bmw        sedan       101.2   176.8         ohc
# 13               bmw        sedan       103.5   189.0         ohc
# 14               bmw        sedan       103.5   193.8         ohc
# 15               bmw        sedan       110.0   197.0         ohc
# 33            jaguar        sedan       113.0   199.6        dohc
# ...

# %%
#Select column body-style:
auto_df['body-style']
#Select column num-of-cylinders:
auto_df[['company','num-of-cylinders']]
# Out:
#            company num-of-cylinders
# index
# 0      alfa-romero             four
# 1      alfa-romero             four
# 2      alfa-romero              six
# 3             audi             four
# 4             audi             five
# ...            ...              ...
# 81      volkswagen             four
# 82      volkswagen             four
# 86      volkswagen             four
# 87           volvo             four
# 88           volvo             four
#
# [61 rows x 2 columns]

# %%
#Select rows by their position:
auto_df_psn = auto_df[10:20]
print(auto_df_psn)

#Select rows by their labels:
auto_df_lab = auto_df_sub.loc[10:20,['company','body-style','price']]
print(auto_df_lab)
# Out:
#          company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 13           bmw      sedan       103.5   189.0         ohc              six
# 14           bmw      sedan       103.5   193.8         ohc              six
# 15           bmw      sedan       110.0   197.0         ohc              six
# 16     chevrolet  hatchback        88.4   141.1           l            three
# 17     chevrolet  hatchback        94.5   155.9         ohc             four
# 18     chevrolet      sedan        94.5   158.8         ohc             four
# 19         dodge  hatchback        93.7   157.3         ohc             four
# 20         dodge  hatchback        93.7   157.3         ohc             four
# 27         honda      wagon        96.5   157.1         ohc             four
# 28         honda      sedan        96.5   175.4         ohc             four
#
#        horsepower  average-mileage    price
# index
# 13            182               16  30760.0
# ...

# %%
#Select rows by their labels:
auto_df_lbl = auto_df_sub.loc[10:20,['company','body-style','price']]
print(auto_df_lbl)

#Select rows by their labels:
auto_df_lbl = auto_df_sub.iloc[10:20,[0, 3, 4, 5]]
print(auto_df_lbl)
# Out:
#       company body-style    price
# index
# 10        bmw      sedan  16925.0
# 11        bmw      sedan  20970.0
# 13        bmw      sedan  30760.0
# 14        bmw      sedan  41315.0
# 15        bmw      sedan  36880.0
#              company  length engine-type num-of-cylinders
# index
# 15               bmw   197.0         ohc              six
# 33            jaguar   199.6        dohc              six
# 34            jaguar   199.6        dohc              six
# 35            jaguar   191.7        ohcv           twelve
# 43             mazda   175.0         ohc             four
# 44     mercedes-benz   190.9         ohc             five
# 45     mercedes-benz   190.9         ohc             five
# 46     mercedes-benz   208.1        ohcv            eight
# 47     mercedes-benz   199.2        ohcv            eight
# 61           porsche   168.9        ohcf              six

# %%
# Create a new data frame from the original sorted by the #column company
auto_df_sort = auto_df.sort_values( by ='company')
auto_df_sort.head()
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 3                 four         102               24  13950.0
# 4                 five         115               18  17450.0

# %%
#sort the data using 2 or more columns:
auto_df_sort = auto_df.sort_values( by =['company', 'price'], ascending = [True, False])
auto_df_sort.head(10)
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 6             audi        wagon       105.8   192.7         ohc
# 4             audi        sedan        99.4   176.6         ohc
# 5             audi        sedan        99.8   177.3         ohc
# 3             audi        sedan        99.8   176.6         ohc
# 14             bmw        sedan       103.5   193.8         ohc
# 15             bmw        sedan       110.0   197.0         ohc
# 13             bmw        sedan       103.5   189.0         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 1                 four         111               21  16500.0
# 2                  six         154               19  16500.0
# 0                 four         111               21  13495.0
# ...

# %%
#agg() method are useful when multiple statistics are computed per column:

auto_df[['length','price']].agg(['min','mean','max'])
# Out:
#           length    price
# min   141.100000   5151.0
# mean  173.098361  15387.0
# max   208.100000  45400.0

# %%
auto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           61 non-null     object
#  1   body-style        61 non-null     object
#  2   wheel-base        61 non-null     float64
#  3   length            61 non-null     float64
#  4   engine-type       61 non-null     object
#  5   num-of-cylinders  61 non-null     object
#  6   horsepower        61 non-null     int64
#  7   average-mileage   61 non-null     int64
#  8   price             58 non-null     float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 4.8+ KB

# %%
auto_df.shape
# Out:
# (61, 9)

# %%
temp_df =auto_df
temp_df.shape
# Out:
# (61, 9)

# %%
temp_df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
temp_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 61 entries, 0 to 88
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           61 non-null     object
#  1   body-style        61 non-null     object
#  2   wheel-base        61 non-null     float64
#  3   length            61 non-null     float64
#  4   engine-type       61 non-null     object
#  5   num-of-cylinders  61 non-null     object
#  6   horsepower        61 non-null     int64
#  7   average-mileage   61 non-null     int64
#  8   price             58 non-null     float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 4.8+ KB

# %%
temp_df = temp_df.drop_duplicates()
temp_df.shape
# Out:
# (60, 9)

# %%
auto_df.columns
# Out:
# Index(['company', 'body-style', 'wheel-base', 'length', 'engine-type',
#        'num-of-cylinders', 'horsepower', 'average-mileage', 'price'],
#       dtype='object')

# %%
auto_df.isnull().sum()
# Out:
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
auto_df.isnull().count()
# Out:
# company             61
# body-style          61
# wheel-base          61
# length              61
# engine-type         61
# num-of-cylinders    61
# horsepower          61
# average-mileage     61
# price               61
# dtype: int64

# %%
auto_df.dropna()
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 0        alfa-romero  convertible        88.6   168.8        dohc
# 1        alfa-romero  convertible        88.6   168.8        dohc
# 2        alfa-romero    hatchback        94.5   171.2        ohcv
# 3               audi        sedan        99.8   176.6         ohc
# 4               audi        sedan        99.4   176.6         ohc
# 5               audi        sedan        99.8   177.3         ohc
# 6               audi        wagon       105.8   192.7         ohc
# 9                bmw        sedan       101.2   176.8         ohc
# 10               bmw        sedan       101.2   176.8         ohc
# 11               bmw        sedan       101.2   176.8         ohc
# 13               bmw        sedan       103.5   189.0         ohc
# 14               bmw        sedan       103.5   193.8         ohc
# 15               bmw        sedan       110.0   197.0         ohc
# ...

# %%
auto_df
# Out:
#            company   body-style  wheel-base  length engine-type  \
# index
# 0      alfa-romero  convertible        88.6   168.8        dohc
# 1      alfa-romero  convertible        88.6   168.8        dohc
# 2      alfa-romero    hatchback        94.5   171.2        ohcv
# 3             audi        sedan        99.8   176.6         ohc
# 4             audi        sedan        99.4   176.6         ohc
# ...            ...          ...         ...     ...         ...
# 81      volkswagen        sedan        97.3   171.7         ohc
# 82      volkswagen        sedan        97.3   171.7         ohc
# 86      volkswagen        sedan        97.3   171.7         ohc
# 87           volvo        sedan       104.3   188.8         ohc
# 88           volvo        wagon       104.3   188.8         ohc
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# 0                 four         111               21  13495.0
# ...

# %%
auto_df.isnull().sum()
# Out:
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
price = auto_df['price']
price.head()
price_mean = price.mean()
price_mean
# Out:
# np.float64(15387.0)

# %%
price.fillna(price_mean, inplace=True)

# %%
auto_df.isnull().sum()
# Out:
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
print(auto_df.price,61)
# Out:
# index
# 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
#        ...
# 81     7975.0
# 82     7995.0
# 86     9995.0
# 87    12940.0
# 88    13415.0
# Name: price, Length: 61, dtype: float64 61

# %%
auto_df['price'].describe()
# Out:
# count       61.00000
# mean     15387.00000
# std      11033.62446
# min       5151.00000
# 25%       6849.00000
# 50%      12940.00000
# 75%      17450.00000
# max      45400.00000
# Name: price, dtype: float64

# %%
auto_df.describe()
# Out:
#        wheel-base      length  horsepower  average-mileage        price
# count   61.000000   61.000000   61.000000        61.000000     61.00000
# mean    98.481967  173.098361  107.852459        25.803279  15387.00000
# std      6.679234   14.021846   53.524398         8.129821  11033.62446
# min     88.400000  141.100000   48.000000        13.000000   5151.00000
# 25%     94.500000  159.100000   68.000000        19.000000   6849.00000
# 50%     96.300000  171.200000  100.000000        25.000000  12940.00000
# 75%    101.200000  177.300000  123.000000        31.000000  17450.00000
# max    120.900000  208.100000  288.000000        47.000000  45400.00000

# %%
auto_df['body-style'].value_counts().head(10)
# Out:
# body-style
# sedan          32
# hatchback      15
# wagon           9
# convertible     3
# hardtop         2
# Name: count, dtype: int64

# %%
auto_df['company'].value_counts().head(10)
# Out:
# company
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# mercedes-benz    4
# audi             4
# volkswagen       4
# mitsubishi       4
# chevrolet        3
# jaguar           3
# Name: count, dtype: int64

# %%
auto_df['price'].value_counts().head(10)
# Out:
# price
# 15387.0    3
# 16500.0    2
# 13950.0    1
# 17450.0    1
# 15250.0    1
# 18920.0    1
# 16430.0    1
# 16925.0    1
# 20970.0    1
# 13495.0    1
# Name: count, dtype: int64

# %%
auto_df.corr(numerical_columns=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 auto_df.corr(numerical_columns=True)
#
# TypeError: DataFrame.corr() got an unexpected keyword argument 'numerical_columns'

# %%
auto_df[auto_df['company'] == "bmw"]
# Out:
#       company body-style  wheel-base  length engine-type num-of-cylinders  \
# index
# 9         bmw      sedan       101.2   176.8         ohc             four
# 10        bmw      sedan       101.2   176.8         ohc             four
# 11        bmw      sedan       101.2   176.8         ohc              six
# 13        bmw      sedan       103.5   189.0         ohc              six
# 14        bmw      sedan       103.5   193.8         ohc              six
# 15        bmw      sedan       110.0   197.0         ohc              six
#
#        horsepower  average-mileage    price
# index
# 9             101               23  16430.0
# 10            101               23  16925.0
# 11            121               21  20970.0
# 13            182               16  30760.0
# 14            182               16  41315.0
# 15            182               15  36880.0

# %%
auto_df[auto_df['price'] >= 25000]
# Out:
#              company   body-style  wheel-base  length engine-type  \
# index
# 13               bmw        sedan       103.5   189.0         ohc
# 14               bmw        sedan       103.5   193.8         ohc
# 15               bmw        sedan       110.0   197.0         ohc
# 33            jaguar        sedan       113.0   199.6        dohc
# 34            jaguar        sedan       113.0   199.6        dohc
# 35            jaguar        sedan       102.0   191.7        ohcv
# 44     mercedes-benz        sedan       110.0   190.9         ohc
# 45     mercedes-benz        wagon       110.0   190.9         ohc
# 46     mercedes-benz        sedan       120.9   208.1        ohcv
# 47     mercedes-benz      hardtop       112.0   199.2        ohcv
# 61           porsche      hardtop        89.5   168.9        ohcf
# 62           porsche  convertible        89.5   168.9        ohcf
#
#       num-of-cylinders  horsepower  average-mileage    price
# index
# ...

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20, 'figure.figsize': (10, 8)}) 
# set font and plot size
auto_df.plot(kind='scatter', x ='average-mileage', y='price',title='Vehicle Revenue(Kshs)vs Mileage')
#df.plot(kind='scatter', x ='average-mileage', y='price', 	title='Revenue(Kshs)vs Mileage');
# Out:
# <Axes: title={'center': 'Vehicle Revenue(Kshs)vs Mileage'}, xlabel='average-mileage', ylabel='price'>

# %%
auto_df['horsepower'].describe()
# Out:
# count     61.000000
# mean     107.852459
# std       53.524398
# min       48.000000
# 25%       68.000000
# 50%      100.000000
# 75%      123.000000
# max      288.000000
# Name: horsepower, dtype: float64

# %%
auto_df['horsepower'].plot(kind="box");
